# %%
from ultralytics import YOLO


model = YOLO("yolo26n.pt")


model.train(
    data="/home/nailf/test_quantization/data/data.yaml",
    epochs=50,
    imgsz=640,
    batch=128,
    optimizer="AdamW",
    flipud=0.0,
    close_mosaic=10,
    cos_lr=True,
    patience=5,
    device=0,
    amp=True,
    workers=8,
    cache=True
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.10.15 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100 80GB PCIe, 81085MiB)
# ...
